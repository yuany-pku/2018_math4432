# %%
from scipy.stats import t, f, norm
import numpy as np
import matplotlib.pyplot as plt

# %%
for df in [1,2,20]:
    x = np.linspace(-5, 5, 100)
    y = t.pdf(x, df)
    plt.plot(x, t.pdf(x,df), label='T-Dis, Degree: '+str(df))
plt.plot(x, norm.pdf(x, 0 ,1), label='Normal(0,1)' )
plt.legend()
plt.show()
